# %%
# !pip install yfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 kB 1.9 MB/s eta 0:00:00
# ...
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 3.8 MB/s eta 0:00:00
# ...
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# ...
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2022.1
#     Uninstalling pytz-2022.1:
#       Successfully uninstalled pytz-2022.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 2.7.1 requires visions[type_image_path]==0.4.1, but you have visions 0.7.5 which is incompatible.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# ...

# %% [markdown]
# Q1. Reset the index, save, and display the first five rows of the tesla_data dataframe using the head function. Upload a screenshot of the results and code from the beginning of Question 1 to the results below.

# %%
import yfinance as yf

ticker_symbol_tesla = "TSLA"

tesla_data = yf.download(ticker_symbol_tesla, start="2023-01-01", end="2023-08-01")

tesla_data.reset_index(inplace=True)

tesla_data.to_csv("tesla_stock_data.csv", index=False)

print(tesla_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-01-03  118.470001  118.800003  104.639999  108.099998  108.099998
# 1 2023-01-04  109.110001  114.589996  107.519997  113.639999  113.639999
# 2 2023-01-05  110.510002  111.750000  107.160004  110.339996  110.339996
# 3 2023-01-06  103.000000  114.389999  101.809998  113.059998  113.059998
# 4 2023-01-09  118.959999  123.519997  117.110001  119.769997  119.769997
#
#       Volume
# 0  231402800
# 1  180389000
# 2  157986300
# 3  220911100
# 4  190284000

# %% [markdown]
# Q3. Reset the index, save, and display the first five rows of the gme_data dataframe using the head function. Upload a screenshot of the results and code from the beginning of Question 1 to the results below.

# %%
import yfinance as yf

stock_symbol = "GME"

gme_data = yf.download(stock_symbol, start="2023-01-01", end="2023-08-01")

gme_data_reset = gme_data.reset_index()

print(gme_data_reset.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Adj Close   Volume
# 0 2023-01-03  18.639999  19.260000  17.090000  17.200001  17.200001  5135200
# 1 2023-01-04  17.250000  17.930000  16.900000  17.320000  17.320000  3939300
# 2 2023-01-05  17.059999  17.260000  15.890000  16.219999  16.219999  6066200
# 3 2023-01-06  16.000000  16.570000  15.410000  16.459999  16.459999  4823400
# 4 2023-01-09  16.650000  17.129999  16.360001  16.379999  16.379999  3522600

# %% [markdown]
# Q5. Plot tesla stock graph, use make_graph function to graph the tesla stock data. also provide the title to the graph

# %%
import yfinance as yf
import matplotlib.pyplot as plt

stock_symbol = "TSLA"

tesla_data = yf.download(stock_symbol, start="2023-01-01", end="2023-08-01")

def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data.index, data['Close'], label='Close Price', color='blue')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.grid(True)
    plt.show()

graph_title = "Tesla Stock Price"

make_graph(tesla_data, graph_title)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# Q6. Plot tesla stock graph, use make_graph function to graph the GameStop stock data. also provide the title to the graph

# %%
import yfinance as yf
import matplotlib.pyplot as plt

stock_symbol = "GME"

gme_data = yf.download(stock_symbol, start="2023-01-01", end="2023-08-01")

def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data.index, data['Close'], label='Close Price', color='green')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.grid(True)
    plt.show()

graph_title = "GameStop Stock Price"

make_graph(gme_data, graph_title)
# Out:
# [*********************100%%**********************]  1 of 1 completed
